# %% [markdown]
# https://gastroranking.es/restaurantes/madrid/boadilla-del-monte/
# <br>Sacar:
# - Nombre del restaurante
# - Valoración del restaurante
# - etiquetas para ver que tipo de comida hacen

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
# Out:
# c:\programdata\miniconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\programdata\miniconda3\lib\site-packages\numpy\.libs\libopenblas.4SP5SUA7CBGXUEOC35YP2ASOICYYEQZZ.gfortran-win_amd64.dll
# c:\programdata\miniconda3\lib\site-packages\numpy\.libs\libopenblas.GK7GX5KEQ4F6UYO3P26ULGBQYHGQO7J4.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %% [markdown]
# ## Metodo para sacar toda la información de la web
# - ca: comunidad autonoma
# - municipio: municipio de la comunidad autonoma del cual queremos saber los restaurantes
# - Devuelve un df con los nombres de los restaurantes, la media de valoración del restaurante y la etiquetas del tipo de comida.

# %%
def gastrorankingData(ca, municipio):
    ca = ca.replace(" ", "-").lower()
    municipio = municipio.replace(" ", "-").lower()
    url = "https://gastroranking.es/restaurantes/"+ca+"/"+municipio+"/"
    print(url)
    pageGastroranking = requests.get(url)
    print("Respuesta: "+str(pageGastroranking.status_code))
    contenidoGastroranking = BeautifulSoup(pageGastroranking.content, 'html.parser')
    
    # sacar el título, ranking y etiquetas de los restaurantes

    df = pd.DataFrame(columns=['nombreRestaurante', 'valoracion', 'etiquetas'])

    nombres = []
    valoraciones = []
    etiquetas = []

    #Nombre
    for h3 in contenidoGastroranking.find_all('h3', class_='restaurantName'):
        for a in h3.find_all('a'):
            nombres.append(a.getText())
    print(nombres)
    print()

    #Valoracion
    for td in contenidoGastroranking.find_all('td', class_='grInfo centerText'):
        for span in td.find_all('span', class_='rankValue'):
            entero = span.find('span', class_='big').getText()
            decimal = span.find('span', class_='decimal').getText()
            numero = str(entero)+str(decimal)
            valoraciones.append(numero)
    print(valoraciones)
    print()

    #etiquetas
    etiquetasTemporal = ""
    for div in contenidoGastroranking.find_all('div', class_='visualClear tags'):
        for a in div.find_all('a', class_='tag'):
            etiquetasTemporal = etiquetasTemporal+" "+a.getText()
        etiquetas.append(etiquetasTemporal)
        etiquetasTemporal = ""
    print(etiquetas)

    print()
    print(str(len(nombres))+" "+str(len(valoraciones))+" "+str(len(etiquetas)))
    
    #insertamos los datos en un dataframe REVISAR
    for n in range(len(nombres)):
        #df.append({'nombreRestaurante' : nombres[n] , 'valoracion' : valoraciones[n], 'etiquetasetiquetas' : etiquetas[n]} , ignore_index=True)
        new_list = [ (nombres[n], valoraciones[n], etiquetas[n])]
        print(new_list)
        dfNew = pd.DataFrame(new_list, columns = ['nombreRestaurante' , 'valoracion', 'etiquetas'])
        df = df.append(dfNew,ignore_index=True)
    return df

# %%
df_restaurantes = gastrorankingData("Madrid", "Boadilla del monte")
# Out:
# https://gastroranking.es/restaurantes/madrid/boadilla-del-monte/
# Respuesta: 200
# ['Proverbium', 'El Bury/parrilla', 'Restaurante Trattoria Piccolo Mio', 'Juan Blanco', 'Restaurante Alilian', 'Fisterra', 'The Burguer Lobby', 'India Gate', 'AmbigÃº', ' La Burguesita ', 'El buey boadilla', 'Meson Jamonero Canete', 'La Via', 'La Ilustracion Gastrobar', 'La Lonja de Boadilla SL.']
#
# ['9,0', '8,8', '8,7', '8,7', '8,6', '8,5', '8,4', '8,4', '8,3', '8,3', '8,3', '8,3', '8,3', '8,2', '8,2']
#
# [' pasta pizza tiramisu trufa atun', ' carne albondigas tarta queso croquetas', ' pasta risotto tiramisu ensalada queso', ' arroz croquetas rabo bonito tarta', ' oreja carne salmon arroz tomate', ' tortilla pulpo tarta tapas alcachofas', ' hamburguesa carne cebolla patatas tarta', ' picante pollo arroz curry cordero', ' tapas cocido patatas', ' hamburguesa patatas carne tarta buey', ' carne buey ensalada tarta lomo', ' jamon torreznos embutidos quesos tapas', ' pasta pizza berenjenas queso pastas', ' cocido tarta tapas arroz', ' pescado marisco carne gambas pulpo']
#
# 15 15 15
# [('Proverbium', '9,0', ' pasta pizza tiramisu trufa atun')]
# [('El Bury/parrilla', '8,8', ' carne albondigas tarta queso croquetas')]
# [('Restaurante Trattoria Piccolo Mio', '8,7', ' pasta risotto tiramisu ensalada queso')]
# [('Juan Blanco', '8,7', ' arroz croquetas rabo bonito tarta')]
# [('Restaurante Alilian', '8,6', ' oreja carne salmon arroz tomate')]
# [('Fisterra', '8,5', ' tortilla pulpo tarta tapas alcachofas')]
# [('The Burguer Lobby', '8,4', ' hamburguesa carne cebolla patatas tarta')]
# [('India Gate', '8,4', ' picante pollo arroz curry cordero')]
# [('AmbigÃº', '8,3', ' tapas cocido patatas')]
# [(' La Burguesita ', '8,3', ' hamburguesa patatas carne tarta buey')]
# [('El buey boadilla', '8,3', ' carne buey ensalada tarta lomo')]
# [('Meson Jamonero Canete', '8,3', ' jamon torreznos embutidos quesos tapas')]
# [('La Via', '8,3', ' pasta pizza berenjenas queso pastas')]
# [('La Ilustracion Gastrobar', '8,2', ' cocido tarta tapas arroz')]
# [('La Lonja de Boadilla SL.', '8,2', ' pescado marisco carne gambas pulpo')]

# %%
df_restaurantes
# Out:
#                     nombreRestaurante valoracion  \
# 0                          Proverbium        9,0
# 1                    El Bury/parrilla        8,8
# 2   Restaurante Trattoria Piccolo Mio        8,7
# 3                         Juan Blanco        8,7
# 4                 Restaurante Alilian        8,6
# 5                            Fisterra        8,5
# 6                   The Burguer Lobby        8,4
# 7                          India Gate        8,4
# 8                             AmbigÃº        8,3
# 9                      La Burguesita         8,3
# 10                   El buey boadilla        8,3
# 11              Meson Jamonero Canete        8,3
# 12                             La Via        8,3
# 13           La Ilustracion Gastrobar        8,2
# 14           La Lonja de Boadilla SL.        8,2
#
#                                    etiquetas
# 0            pasta pizza tiramisu trufa atun
# 1     carne albondigas tarta queso croquetas
# 2      pasta risotto tiramisu ensalada queso
# 3          arroz croquetas rabo bonito tarta
# 4            oreja carne salmon arroz tomate
# 5      tortilla pulpo tarta tapas alcachofas
# 6    hamburguesa carne cebolla patatas tarta
# 7          picante pollo arroz curry cordero
# 8                       tapas cocido patatas
# 9       hamburguesa patatas carne tarta buey
# 10            carne buey ensalada tarta lomo
# 11    jamon torreznos embutidos quesos tapas
# 12       pasta pizza berenjenas queso pastas
# 13                  cocido tarta tapas arroz
# 14        pescado marisco carne gambas pulpo
